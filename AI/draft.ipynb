# %% [markdown]
# # dataset.xlsx

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("dataset.xlsx")

# %%
df = data.iloc[:, :47]

# %%
to_drop = ["Serum Glucose", "Mycoplasma pneumoniae"]
df = df.drop(to_drop, axis = 1)

# %%
df.iloc[1]
# Out:
# Patient ID                                               126e9dd13932f68
# Patient age quantile                                                  17
# SARS-Cov-2 exam result                                          negative
# Patient addmited to regular ward (1=yes, 0=no)                         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)                  0
# Patient addmited to intensive care unit (1=yes, 0=no)                  0
# Hematocrit                                                      0.236515
# Hemoglobin                                                    -0.0223403
# Platelets                                                      -0.517413
# Mean platelet volume                                           0.0106766
# Red blood Cells                                                 0.102004
# Lymphocytes                                                     0.318366
# Mean corpuscular hemoglobin concentration (MCHC)                -0.95079
# ...

# %%
df.dropna()
# Out:
#            Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 1     126e9dd13932f68                    17               negative
# 30    ebdd7c67fcb21b4                     9               negative
# 87    26000ea3dba0de1                    17               negative
# 133   33fd6f1c08760a1                    17               negative
# 145   1205a978ff0ef00                    12               negative
# 193   c7493375e3a576c                     3               negative
# 196   26bc5c882b8bebc                    18               negative
# 205   671655cb4b17c2e                     3               negative
# 226   0f77fabc0fe7a6c                    13               negative
# 671   0f2c3bd3954f19e                     7               negative
# 732   31bad60781945d3                     6               negative
# 915   72eb26d2d535794                    16               negative
# 1027  e64b89d80b931a7                    11               negative
# ...

# %% [markdown]
# # COVID19_line_list_data.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
PATH = os.path.join("data", "COVID19_line_list_data.csv")
data = pd.read_csv(PATH)

# %%
data
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %% [markdown]
# # 112000.xlsx

# %%
import pandas as pd
import numpy as np
import os

# %%
PATH = os.path.join("data", "112000.xlsx")
data = pd.read_excel(PATH)

# %%
data["corona_result"] = data["corona_result"].map({"חיובי": 1, "שלילי": 0})

# %%
data
# Out:
#         test_date  cough  fever  sore_throat  shortness_of_breath  head_ache  \
# 0      2020-03-22    1.0    0.0            0                    0          0
# 1      2020-03-22    1.0    1.0            0                    0          0
# 2      2020-03-22    0.0    1.0            0                    0          0
# 3      2020-03-22    1.0    1.0            0                    0          0
# 4      2020-03-22    1.0    0.0            0                    0          0
# ...           ...    ...    ...          ...                  ...        ...
# 112340 2020-04-11    0.0    0.0            0                    0          0
# 112341 2020-04-11    0.0    0.0            0                    0          0
# 112342 2020-04-11    0.0    0.0            0                    0          0
# 112343 2020-04-11    0.0    0.0            0                    0          0
# 112344 2020-04-11    0.0    0.0            0                    0          0
#
# ...

# %%
data["gender"] = data["gender"].map({"נקבה": "female", "זכר": "male"})

# %%
data
# Out:
#         test_date  cough  fever  sore_throat  shortness_of_breath  head_ache  \
# 0      2020-03-22    1.0    0.0            0                    0          0
# 1      2020-03-22    1.0    1.0            0                    0          0
# 2      2020-03-22    0.0    1.0            0                    0          0
# 3      2020-03-22    1.0    1.0            0                    0          0
# 4      2020-03-22    1.0    0.0            0                    0          0
# ...           ...    ...    ...          ...                  ...        ...
# 112340 2020-04-11    0.0    0.0            0                    0          0
# 112341 2020-04-11    0.0    0.0            0                    0          0
# 112342 2020-04-11    0.0    0.0            0                    0          0
# 112343 2020-04-11    0.0    0.0            0                    0          0
# 112344 2020-04-11    0.0    0.0            0                    0          0
#
# ...

# %%
data.to_csv("train.csv", index = False)

# %% [markdown]
# # Reading

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#          test_date  cough  fever  sore_throat  shortness_of_breath  head_ache  \
# 0       2020-03-22    1.0    0.0            0                    0          0
# 1       2020-03-22    1.0    1.0            0                    0          0
# 2       2020-03-22    0.0    1.0            0                    0          0
# 3       2020-03-22    1.0    1.0            0                    0          0
# 4       2020-03-22    1.0    0.0            0                    0          0
# ...            ...    ...    ...          ...                  ...        ...
# 112340  2020-04-11    0.0    0.0            0                    0          0
# 112341  2020-04-11    0.0    0.0            0                    0          0
# 112342  2020-04-11    0.0    0.0            0                    0          0
# 112343  2020-04-11    0.0    0.0            0                    0          0
# 112344  2020-04-11    0.0    0.0            0                    0          0
#
# ...
